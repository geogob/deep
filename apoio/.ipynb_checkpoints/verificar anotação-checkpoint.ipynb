# %% [markdown]
# <h1>Ver a anotação</h1>

# %%
#Importação das bibliotecas
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


#Carregando a imagem
img = cv2.imread("/home/george/anotacao natanael/original/02.jpg")


"""
Lendo de um arquivo de texto

a = pd.read_csv('/home/george/deep/CNNs/podocytes/annotation/02.csv', header=None)
anotacao = a.values
"""
df = pd.read_fwf('/home/george/deep/CNNs/podocytes/annotation/test.txt', header=None)
print(df.shape)
# Out:
# (1, 40)

# %%
dados = np.array(anotacao)

#[[284.0, 45.0], [305.0, 64.0], [440.0, 156.0], [419.0, 127.0], [338.0, 267.0], [362.0, 297.0], [253.0, 268.0], [276.0, 295.0], [203.0, 299.0], [222.0, 266.0], [118.0, 228.0], [95.0, 255.0], [43.0, 220.0], [68.0, 241.0], [93.0, 289.0], [75.0, 311.0], [92.0, 321.0], [117.0, 339.0], [178.0, 393.0], [199.0, 417.0], [62.0, 100.0], [40.0, 128.0], [130.0, 83.0], [151.0, 109.0], [343.0, 390.0], [324.0, 409.0]]

#dados = np.array(dados)
px=[]
py=[]
#print dados.size
for x,y in dados:
    px=px+[int(x)]
    py=py+[int(y)]
    #print x, y
    
px = np.array(px)
py= np.array(py)
tam = px.size

print ("tam",tam)

i=0
while(i<tam-1):  
    cv2.rectangle(img, (px[i], py[i]), (px[i+1], py[i+1]), (0,255,0), 2)
    i=i+2
    
#Convertendo as cores
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Exibindo
plt.imshow(img)
# Out:
# tam 20
